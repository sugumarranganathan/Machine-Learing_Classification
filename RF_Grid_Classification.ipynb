# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
print(np.__version__)
# Out:
# 2.0.2

# %%
# Reading the Dataset
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset.head(133)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 128  15722758    Male   30            17000          0
# 129  15792102  Female   26            84000          0
# 130  15675185    Male   31            58000          0
# 131  15801247    Male   33            31000          0
# 132  15725660    Male   30            87000          0
#
# [133 rows x 5 columns]

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_= sc.fit_transform(X_train)
X_test_= sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['gini','entropy'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]}



grid = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1')

# fitting the model for grid search
grid.fit(X_train_, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 20 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 436, in _validate_params
# ...

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test_)


from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)



# print classification report
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001249      0.000329         0.000000        0.000000
# 1        0.000896      0.000016         0.000000        0.000000
# 2        0.031850      0.001291         0.007754        0.000922
# 3        0.284915      0.015532         0.019291        0.001210
# 4        0.032743      0.001324         0.006756        0.000194
# 5        0.294381      0.016687         0.018700        0.000826
# 6        0.001251      0.000468         0.000000        0.000000
# 7        0.001701      0.000799         0.000000        0.000000
# 8        0.030278      0.002036         0.006811        0.000745
# 9        0.288375      0.015018         0.017666        0.000155
# 10       0.029602      0.000404         0.006400        0.000059
# 11       0.267059      0.027937         0.016380        0.002819
#
#    param_criterion param_max_features  param_n_estimators  \
# 0             gini               auto                  10
# ...

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 100}: 0.9256751954513149

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[79  6]
#  [ 4 45]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        85
#            1       0.88      0.92      0.90        49
#
#     accuracy                           0.93       134
#    macro avg       0.92      0.92      0.92       134
# weighted avg       0.93      0.93      0.93       134

# %%
table_pr=pd.DataFrame()

# %%
print(X_test)
# Out:
#      Age  EstimatedSalary  Gender_Male
# 132   30            87000         True
# 309   38            50000        False
# 341   35            75000         True
# 196   30            79000        False
# 246   35            50000        False
# ..   ...              ...          ...
# 168   29           148000         True
# 150   26            15000        False
# 393   60            42000         True
# 66    24            19000         True
# 240   42           149000         True
#
# [134 rows x 3 columns]

# %%
table_pr['Age']=X_test["Age"]
table_pr['Gender_male']=X_test["Gender_Male"]
table_pr['Estimated_Salary']=X_test["EstimatedSalary"]
table_pr['Actual']=y_test
table_pr['Predicted']=grid_predictions

# %%
table_pr.head(134)
# Out:
#      Age  Gender_male  Estimated_Salary  Actual  Predicted
# 132   30         True             87000       0          0
# 309   38        False             50000       0          0
# 341   35         True             75000       0          0
# 196   30        False             79000       0          0
# 246   35        False             50000       0          0
# ..   ...          ...               ...     ...        ...
# 168   29         True            148000       1          1
# 150   26        False             15000       0          0
# 393   60         True             42000       1          1
# 66    24         True             19000       0          0
# 240   42         True            149000       1          1
#
# [134 rows x 5 columns]

# %%
table_pr.to_csv("cm.csv",index=False)

# %%
# Add the predicted values to the table_pr DataFrame (which contains the test set data)
table_pr['Predicted'] = grid_predictions

# Merge the table_pr DataFrame with the original dataset DataFrame based on the index
dataset = dataset.merge(table_pr[['Predicted']], left_index=True, right_index=True, how='left')

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1628110320.py in <cell line: 0>()
#       1 # Create a DataFrame with the input values
# ----> 2 future_prediction_input = pd.DataFrame([[age_input, estimated_salary_input, sex_male_input]], columns=['Age', 'EstimatedSalary', 'Gender_Male'])
#       3
#       4 # Scale the input features
#       5 future_prediction_input_scaled = sc.transform(future_prediction_input)
#
# NameError: name 'age_input' is not defined

# %%
age_input=float(input("Age:"))
estimated_salary_input=float(input("Estimated Salary:"))
sex_male_input=int(input("Gender Male (0 for Female, 1 for Male):"))
# Out:
# Age:33
# Estimated Salary:30000
# Gender Male (0 for Female, 1 for Male):1

# %%
# Create a DataFrame with the input values
future_prediction_input = pd.DataFrame([[age_input, estimated_salary_input, sex_male_input]], columns=['Age', 'EstimatedSalary', 'Gender_Male'])

# Scale the input features
future_prediction_input_scaled = sc.transform(future_prediction_input)

# Make the prediction using the best model from the grid search
Future_Prediction=grid.predict(future_prediction_input_scaled)

# Print the prediction
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[0]

# %%
result=Future_Prediction

# %%
result
# Out:
# array([0])
